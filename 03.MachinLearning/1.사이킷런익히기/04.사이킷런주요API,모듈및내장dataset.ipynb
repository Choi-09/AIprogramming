# %% [markdown]
# # 4. 사이킷런 주요 API / 모듈 및 내장 dataset

# %% [markdown]
# ## 1. Estimator
# - 학습: fit()
# - 예측: predict()

# %% [markdown]
# ### 1-1) 회귀 (Regressor)

# %% [markdown]
# #### (1) 회귀 구현 클래스
# 1) LinearRegression
#
# 2) Ridge
#
# 3) Lasso
#
# 4) RandomForestRegressor
#
# 5) GradientBoostinfRegressor

# %% [markdown]
# ### 1-2) 분류 (Classifier)

# %% [markdown]
# #### (1) 분류 구현 클래스
# 1) DecisionTreeClassifier
#
# 2) RandomForestClassifier
#
# 3) GradientBoostinfClassifier
#
# 4) GaussianNB
#
# 5) SVC

# %% [markdown]
# ## 2. 사이킷런 주요 모듈
# ![사이킷런 주요모듈.png](attachment:%EC%82%AC%EC%9D%B4%ED%82%B7%EB%9F%B0-%EC%A3%BC%EC%9A%94-%EB%AA%A8%EB%93%88.png)
